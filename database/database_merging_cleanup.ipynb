# %%
#Import Dependencies
import pandas as pd
import sqlite3
from sqlite3 import Error

# %%
con = sqlite3.connect('../../DataBase/sqlite_db.sqlite')

# %%
cursor = con.cursor()

# %%
df_test = pd.DataFrame(pd.read_sql_query(f'select * from QB_Stats as a inner join QB_Extra_Stats as b on a.PlayerID = b.PlayerPlayerId and a.Year=b.Year', con))
df_test
# Out:
#      index  Rank  PlayerID             Name Team Position  Played  \
# 0        0     1     19801       Josh Allen  BUF       QB      17
# 1        1     2     21681   Justin Herbert  LAC       QB      17
# 2        2     3      4314        Tom Brady   TB       QB      17
# 3        3     4     18890  Patrick Mahomes   KC       QB      17
# 4        4     5      2593    Aaron Rodgers   GB       QB      16
# ..     ...   ...       ...              ...  ...      ...     ...
# 126    269    30     13799   Ryan Tannehill  MIA       QB      11
# 127    270    31      6739       Alex Smith  WAS       QB      10
# 128    271    32       611       Joe Flacco  BAL       QB       9
# 129    272    33     19330     Nick Mullens   SF       QB       8
# 130    273    34     19763       Josh Rosen  ARI       QB      14
#
#      PassingCompletions  PassingAttempts  PassingCompletionPercentage  ...  \
# 0                   409              646                         63.3  ...
# 1                   443              672                         65.9  ...
# 2                   485              719                         67.5  ...
# 3                   436              658                         66.3  ...
# 4                   366              531                         68.9  ...
# ..                  ...              ...                          ...  ...
# 126                 176              274                         64.2  ...
# 127                 205              328                         62.5  ...
# 128                 232              379                         61.2  ...
# 129                 176              274                         64.2  ...
# 130                 217              393                         55.2  ...
#
#      MoneyThrows  TouchdownRate  ProtectionRate  \
# 0             29           5.58           77.94
# 1             30           5.65           88.62
# 2             44           5.98           92.98
# 3             32           5.62           85.27
# 4             37           6.96           88.94
# ..           ...            ...             ...
# 126            4           6.20           80.60
# 127            7           3.00           87.20
# 128           10           3.20           85.50
# 129           12           4.70           74.10
# 130           13           2.80           73.30
#
#      PressuredCompletionPercentage  AirYards  AirYardsPerGame  \
# 0                            37.83    2785.0           163.82
# 1                            41.34    2678.0           157.52
# 2                            46.84    2792.0           164.23
# 3                            40.65    2219.0           130.52
# 4                            39.75    1956.0           122.25
# ..                             ...       ...              ...
# 126                          27.50    2306.0           209.60
# 127                          27.40    2720.0           272.00
# 128                          31.40    3339.0           371.00
# 129                          35.30    1960.0           245.00
# 130                          33.60    3324.0           237.40
#
#      AirYardsPerAttempt  DeepBallAttempts  DeepBallCompletionPercentage  Year
# 0                  4.31                80                         42.50  2021
# 1                  3.98                71                         43.66  2021
# 2                  3.88                87                         40.22  2021
# 3                  3.37                79                         36.70  2021
# 4                  3.68                69                         39.13  2021
# ..                  ...               ...                           ...   ...
# 126                8.40                38                         26.30  2018
# 127                8.30                39                         30.80  2018
# 128                8.80                51                         25.50  2018
# 129                7.20                19                         31.60  2018
# 130                8.50                56                         26.80  2018
#
# [131 rows x 42 columns]

# %%
positions = ['qb', 'rb', 'te', 'wr']
df_list = []
for x in positions:
    df = f'{x}_df'
    table = f'{x.upper()}_Stats'
    table2 = f'{x.upper()}_Extra_Stats'
    df = pd.DataFrame(pd.read_sql_query(f'select * from {table} as a inner join {table2} as b on a.PlayerID = b.PlayerPlayerId and a.Year=b.Year', con))
    df_list.append(df)

# %%
len(df_list)
# Out:
# 4

# %%
type(df_list[1])
# Out:
# pandas.core.frame.DataFrame

# %%
qb_df = pd.DataFrame()
rb_df = pd.DataFrame()
te_df = pd.DataFrame()
wr_df = pd.DataFrame()

# %%
qb_df = pd.concat([df_list[0], qb_df], ignore_index=True)
rb_df = pd.concat([df_list[1], rb_df], ignore_index=True)
te_df = pd.concat([df_list[2], te_df], ignore_index=True)
wr_df = pd.concat([df_list[3], wr_df], ignore_index=True)

# %%
qb_df.head()
# Out:
#    index  Rank  PlayerID             Name Team Position  Played  \
# 0      0     1     19801       Josh Allen  BUF       QB      17
# 1      1     2     21681   Justin Herbert  LAC       QB      17
# 2      2     3      4314        Tom Brady   TB       QB      17
# 3      3     4     18890  Patrick Mahomes   KC       QB      17
# 4      4     5      2593    Aaron Rodgers   GB       QB      16
#
#    PassingCompletions  PassingAttempts  PassingCompletionPercentage  ...  \
# 0                 409              646                         63.3  ...
# 1                 443              672                         65.9  ...
# 2                 485              719                         67.5  ...
# 3                 436              658                         66.3  ...
# 4                 366              531                         68.9  ...
#
#    MoneyThrows  TouchdownRate  ProtectionRate  PressuredCompletionPercentage  \
# 0           29           5.58           77.94                          37.83
# 1           30           5.65           88.62                          41.34
# 2           44           5.98           92.98                          46.84
# 3           32           5.62           85.27                          40.65
# 4           37           6.96           88.94                          39.75
#
#    AirYards  AirYardsPerGame  AirYardsPerAttempt  DeepBallAttempts  \
# 0    2785.0           163.82                4.31                80
# 1    2678.0           157.52                3.98                71
# 2    2792.0           164.23                3.88                87
# 3    2219.0           130.52                3.37                79
# 4    1956.0           122.25                3.68                69
#
#    DeepBallCompletionPercentage  Year
# 0                         42.50  2021
# 1                         43.66  2021
# 2                         40.22  2021
# 3                         36.70  2021
# 4                         39.13  2021
#
# [5 rows x 42 columns]

# %%
qb_df.columns
# Out:
# Index(['index', 'Rank', 'PlayerID', 'Name', 'Team', 'Position', 'Played',
#        'PassingCompletions', 'PassingAttempts', 'PassingCompletionPercentage',
#        'PassingYards', 'PassingYardsPerAttempt', 'PassingTouchdowns',
#        'PassingInterceptions', 'PassingRating', 'RushingAttempts',
#        'RushingYards', 'RushingYardsPerAttempt', 'RushingTouchdowns',
#        'FantasyPointsPerGame', 'FantasyPoints', 'Year', 'index', 'Rank',
#        'PlayerPlayerId', 'PlayerShortName', 'PlayerAgeExact',
#        'PassAttemptsPerGame', 'PassingYards', 'CompletionPercentage',
#        'PassingTouchdowns', 'Interceptions', 'MoneyThrows', 'TouchdownRate',
#        'ProtectionRate', 'PressuredCompletionPercentage', 'AirYards',
#        'AirYardsPerGame', 'AirYardsPerAttempt', 'DeepBallAttempts',
#        'DeepBallCompletionPercentage', 'Year'],
#       dtype='object')

# %%
def getDuplicateColumns(df):
  
    # Create an empty set
    duplicateColumnNames = set()
      
    # Iterate through all the columns 
    # of dataframe
    for x in range(df.shape[1]):
          
        # Take column at xth index.
        col = df.iloc[:, x]
          
        # Iterate through all the columns in
        # DataFrame from (x + 1)th index to
        # last index
        for y in range(x + 1, df.shape[1]):
              
            # Take column at yth index.
            otherCol = df.iloc[:, y]
               # Check if two columns at x & y
            # index are equal or not,
            # if equal then adding 
            # to the set
            if col.equals(otherCol):
                duplicateColumnNames.add(df.columns.values[y])
                  
    # Return list of unique column names 
    # whose contents are duplicates.
    return list(duplicateColumnNames)

# %%
dupColumnsNames = []
for x in range(0, len(positions)):
    col_name = f'dupColumns_{positions[x]}'
    dupColumnsNames.append(col_name)

# %%
dupColumns = []
for i in range(0, len(dupColumnsNames)):
    dupColumns.append(getDuplicateColumns(df_list[i]))
dupColumns
# Out:
# [['Interceptions', 'PlayerPlayerId', 'Year', 'PassingTouchdowns'],
#  ['Year', 'PlayerPlayerId', 'Receptions'],
#  ['ReceivingTDs', 'Year', 'Receptions', 'PlayerPlayerId', 'Targets.1'],
#  ['Targets.1', 'Year', 'PlayerPlayerId', 'Receptions']]

# %%
for frame in df_list:
    print(frame.columns)
# Out:
# Index(['index', 'Rank', 'PlayerID', 'Name', 'Team', 'Position', 'Played',
#        'PassingCompletions', 'PassingAttempts', 'PassingCompletionPercentage',
#        'PassingYards', 'PassingYardsPerAttempt', 'PassingTouchdowns',
#        'PassingInterceptions', 'PassingRating', 'RushingAttempts',
#        'RushingYards', 'RushingYardsPerAttempt', 'RushingTouchdowns',
#        'FantasyPointsPerGame', 'FantasyPoints', 'Year', 'index', 'Rank',
#        'PlayerPlayerId', 'PlayerShortName', 'PlayerAgeExact',
#        'PassAttemptsPerGame', 'PassingYards', 'CompletionPercentage',
#        'PassingTouchdowns', 'Interceptions', 'MoneyThrows', 'TouchdownRate',
#        'ProtectionRate', 'PressuredCompletionPercentage', 'AirYards',
#        'AirYardsPerGame', 'AirYardsPerAttempt', 'DeepBallAttempts',
#        'DeepBallCompletionPercentage', 'Year'],
#       dtype='object')
# Index(['index', 'Rank', 'PlayerID', 'Name', 'Team', 'Position', 'Played',
#        'RushingAttempts', 'RushingYards', 'RushingYardsPerAttempt',
#        'RushingTouchdowns', 'ReceivingTargets', 'Receptions', 'ReceivingYards',
#        'ReceivingTouchdowns', 'Fumbles', 'FumblesLost', 'FantasyPointsPerGame',
#        'FantasyPoints', 'Year', 'index', 'Rank', 'PlayerPlayerId',
#        'PlayerShortName', 'PlayerAgeExact', 'Carries', 'RushingYards',
#        'YardsPerCarry', 'RushingTouchdowns', 'Targets', 'Receptions',
#        'ReceivingYards', 'ReceivingTDs', 'SnapShare', 'OpportunityShare',
#        'ShotgunCarryRate', 'ShotgunYardsPerCarry', 'UnderCenterCarryRate',
#        'UnderCenterYardsPerCarry', 'AverageDefendersInTheBox',
#        'StackedFrontCarryRate', 'BaseFrontCarryRate', 'LightFrontCarryRate',
#        'Year'],
#       dtype='object')
# Index(['index', 'Rank', 'PlayerID', 'Name', 'Team', 'Position', 'Played',
#        'ReceivingTargets', 'Receptions', 'ReceptionPercentage',
#        'ReceivingYards', 'ReceivingTouchdowns', 'ReceivingLong',
#        'ReceivingYardsPerTarget', 'ReceivingYardsPerReception',
#        'RushingAttempts', 'RushingYards', 'RushingYardsPerAttempt',
#        'RushingTouchdowns', 'Fumbles', 'FumblesLost', 'FantasyPointsPerGame',
#        'FantasyPoints', 'Year', 'index', 'Rank', 'PlayerPlayerId',
#        'PlayerShortName', 'Targets', 'Receptions', 'ReceivingYards',
#        'ReceivingTDs', 'HogRate', 'SnapShare', 'AverageTargetDistance',
#        'AirYards', 'AirYardsPerGame', 'AirYardsPerReception', 'Targets.1',
#        'RedZoneTargets', 'EndzoneTargets', 'TargetAccuracy', 'TargetShare',
#        'FantasyPointsPerTarget', 'Year'],
#       dtype='object')
# Index(['index', 'Rank', 'PlayerID', 'Name', 'Team', 'Position', 'Played',
#        'ReceivingTargets', 'Receptions', 'ReceptionPercentage',
#        'ReceivingYards', 'ReceivingTouchdowns', 'ReceivingLong',
#        'ReceivingYardsPerTarget', 'ReceivingYardsPerReception',
#        'RushingAttempts', 'RushingYards', 'RushingYardsPerAttempt',
#        'RushingTouchdowns', 'Fumbles', 'FumblesLost', 'FantasyPointsPerGame',
#        'FantasyPoints', 'Year', 'index', 'Rank', 'PlayerPlayerId',
#        'PlayerShortName', 'Targets', 'Receptions', 'ReceivingYards',
#        'ReceivingTDs', 'HogRate', 'SnapShare', 'AverageTargetDistance',
#        'AirYards', 'AirYardsPerGame', 'AirYardsPerReception', 'Targets.1',
#        'RedZoneTargets', 'EndzoneTargets', 'TargetAccuracy', 'TargetShare',
#        'FantasyPointsPerTarget', 'Year'],
#       dtype='object')

# %%
for frame in df_list:
    print(len(frame.columns))

# %%
df_list2 = []
for frame in df_list:
    frame2 = frame.loc[:,~frame.columns.duplicated()].copy()
    df_list2.append(frame2)

# %%
for frame in df_list2:
    print(len(frame.columns))
# Out:
# 37
# 37
# 40
# 40

# %%
for frame in df_list2:
    print(frame.columns)
# Out:
# Index(['index', 'Rank', 'PlayerID', 'Name', 'Team', 'Position', 'Played',
#        'PassingCompletions', 'PassingAttempts', 'PassingCompletionPercentage',
#        'PassingYards', 'PassingYardsPerAttempt', 'PassingTouchdowns',
#        'PassingInterceptions', 'PassingRating', 'RushingAttempts',
#        'RushingYards', 'RushingYardsPerAttempt', 'RushingTouchdowns',
#        'FantasyPointsPerGame', 'FantasyPoints', 'Year', 'PlayerPlayerId',
#        'PlayerShortName', 'PlayerAgeExact', 'PassAttemptsPerGame',
#        'CompletionPercentage', 'Interceptions', 'MoneyThrows', 'TouchdownRate',
#        'ProtectionRate', 'PressuredCompletionPercentage', 'AirYards',
#        'AirYardsPerGame', 'AirYardsPerAttempt', 'DeepBallAttempts',
#        'DeepBallCompletionPercentage'],
#       dtype='object')
# Index(['index', 'Rank', 'PlayerID', 'Name', 'Team', 'Position', 'Played',
#        'RushingAttempts', 'RushingYards', 'RushingYardsPerAttempt',
#        'RushingTouchdowns', 'ReceivingTargets', 'Receptions', 'ReceivingYards',
#        'ReceivingTouchdowns', 'Fumbles', 'FumblesLost', 'FantasyPointsPerGame',
#        'FantasyPoints', 'Year', 'PlayerPlayerId', 'PlayerShortName',
#        'PlayerAgeExact', 'Carries', 'YardsPerCarry', 'Targets', 'ReceivingTDs',
#        'SnapShare', 'OpportunityShare', 'ShotgunCarryRate',
#        'ShotgunYardsPerCarry', 'UnderCenterCarryRate',
#        'UnderCenterYardsPerCarry', 'AverageDefendersInTheBox',
#        'StackedFrontCarryRate', 'BaseFrontCarryRate', 'LightFrontCarryRate'],
#       dtype='object')
# Index(['index', 'Rank', 'PlayerID', 'Name', 'Team', 'Position', 'Played',
#        'ReceivingTargets', 'Receptions', 'ReceptionPercentage',
#        'ReceivingYards', 'ReceivingTouchdowns', 'ReceivingLong',
#        'ReceivingYardsPerTarget', 'ReceivingYardsPerReception',
#        'RushingAttempts', 'RushingYards', 'RushingYardsPerAttempt',
#        'RushingTouchdowns', 'Fumbles', 'FumblesLost', 'FantasyPointsPerGame',
#        'FantasyPoints', 'Year', 'PlayerPlayerId', 'PlayerShortName', 'Targets',
#        'ReceivingTDs', 'HogRate', 'SnapShare', 'AverageTargetDistance',
#        'AirYards', 'AirYardsPerGame', 'AirYardsPerReception', 'Targets.1',
#        'RedZoneTargets', 'EndzoneTargets', 'TargetAccuracy', 'TargetShare',
#        'FantasyPointsPerTarget'],
#       dtype='object')
# Index(['index', 'Rank', 'PlayerID', 'Name', 'Team', 'Position', 'Played',
#        'ReceivingTargets', 'Receptions', 'ReceptionPercentage',
#        'ReceivingYards', 'ReceivingTouchdowns', 'ReceivingLong',
#        'ReceivingYardsPerTarget', 'ReceivingYardsPerReception',
#        'RushingAttempts', 'RushingYards', 'RushingYardsPerAttempt',
#        'RushingTouchdowns', 'Fumbles', 'FumblesLost', 'FantasyPointsPerGame',
#        'FantasyPoints', 'Year', 'PlayerPlayerId', 'PlayerShortName', 'Targets',
#        'ReceivingTDs', 'HogRate', 'SnapShare', 'AverageTargetDistance',
#        'AirYards', 'AirYardsPerGame', 'AirYardsPerReception', 'Targets.1',
#        'RedZoneTargets', 'EndzoneTargets', 'TargetAccuracy', 'TargetShare',
#        'FantasyPointsPerTarget'],
#       dtype='object')

# %%
dupColumns2 = []
for i in range(0, len(dupColumnsNames)):
    dupColumns2.append(getDuplicateColumns(df_list2[i]))
dupColumns2
# Out:
# [['Interceptions', 'PlayerPlayerId'],
#  ['PlayerPlayerId'],
#  ['Targets.1', 'PlayerPlayerId', 'ReceivingTDs'],
#  ['Targets.1', 'PlayerPlayerId']]

# %%
for i in range(0, len(df_list2)):
    df_list2[i].drop(columns = dupColumns2[i], axis = 1, inplace = True)

# %%
for frame in df_list2:
    print(frame.columns)
# Out:
# Index(['Rank', 'PlayerID', 'Name', 'Team', 'Position', 'Played',
#        'PassingCompletions', 'PassingAttempts', 'PassingCompletionPercentage',
#        'PassingYards', 'PassingYardsPerAttempt', 'PassingTouchdowns',
#        'PassingInterceptions', 'PassingRating', 'RushingAttempts',
#        'RushingYards', 'RushingYardsPerAttempt', 'RushingTouchdowns',
#        'FantasyPointsPerGame', 'FantasyPoints', 'Year', 'PlayerShortName',
#        'PlayerAgeExact', 'PassAttemptsPerGame', 'CompletionPercentage',
#        'MoneyThrows', 'TouchdownRate', 'ProtectionRate',
#        'PressuredCompletionPercentage', 'AirYards', 'AirYardsPerGame',
#        'AirYardsPerAttempt', 'DeepBallAttempts',
#        'DeepBallCompletionPercentage'],
#       dtype='object')
# Index(['Rank', 'PlayerID', 'Name', 'Team', 'Position', 'Played',
#        'RushingAttempts', 'RushingYards', 'RushingYardsPerAttempt',
#        'RushingTouchdowns', 'ReceivingTargets', 'Receptions', 'ReceivingYards',
#        'ReceivingTouchdowns', 'Fumbles', 'FumblesLost', 'FantasyPointsPerGame',
#        'FantasyPoints', 'Year', 'PlayerShortName', 'PlayerAgeExact', 'Carries',
#        'YardsPerCarry', 'Targets', 'ReceivingTDs', 'SnapShare',
#        'OpportunityShare', 'ShotgunCarryRate', 'ShotgunYardsPerCarry',
#        'UnderCenterCarryRate', 'UnderCenterYardsPerCarry',
#        'AverageDefendersInTheBox', 'StackedFrontCarryRate',
#        'BaseFrontCarryRate', 'LightFrontCarryRate'],
#       dtype='object')
# Index(['Rank', 'PlayerID', 'Name', 'Team', 'Position', 'Played',
#        'ReceivingTargets', 'Receptions', 'ReceptionPercentage',
#        'ReceivingYards', 'ReceivingTouchdowns', 'ReceivingLong',
#        'ReceivingYardsPerTarget', 'ReceivingYardsPerReception',
#        'RushingAttempts', 'RushingYards', 'RushingYardsPerAttempt',
#        'RushingTouchdowns', 'Fumbles', 'FumblesLost', 'FantasyPointsPerGame',
#        'FantasyPoints', 'Year', 'PlayerShortName', 'Targets', 'HogRate',
#        'SnapShare', 'AverageTargetDistance', 'AirYards', 'AirYardsPerGame',
#        'AirYardsPerReception', 'RedZoneTargets', 'EndzoneTargets',
#        'TargetAccuracy', 'TargetShare', 'FantasyPointsPerTarget'],
#       dtype='object')
# Index(['Rank', 'PlayerID', 'Name', 'Team', 'Position', 'Played',
#        'ReceivingTargets', 'Receptions', 'ReceptionPercentage',
#        'ReceivingYards', 'ReceivingTouchdowns', 'ReceivingLong',
#        'ReceivingYardsPerTarget', 'ReceivingYardsPerReception',
#        'RushingAttempts', 'RushingYards', 'RushingYardsPerAttempt',
#        'RushingTouchdowns', 'Fumbles', 'FumblesLost', 'FantasyPointsPerGame',
#        'FantasyPoints', 'Year', 'PlayerShortName', 'Targets', 'ReceivingTDs',
#        'HogRate', 'SnapShare', 'AverageTargetDistance', 'AirYards',
#        'AirYardsPerGame', 'AirYardsPerReception', 'RedZoneTargets',
#        'EndzoneTargets', 'TargetAccuracy', 'TargetShare',
#        'FantasyPointsPerTarget'],
#       dtype='object')

# %%
for frame in df_list2:
    frame.drop(columns = 'index', axis = 1, inplace= True)

# %%
for frame in df_list2:
    print(frame.isnull().sum())
# Out:
# Rank                             0
# PlayerID                         0
# Name                             0
# Team                             0
# Position                         0
# Played                           0
# PassingCompletions               0
# PassingAttempts                  0
# PassingCompletionPercentage      0
# PassingYards                     0
# PassingYardsPerAttempt           0
# PassingTouchdowns                0
# PassingInterceptions             0
# PassingRating                    0
# RushingAttempts                  0
# RushingYards                     0
# RushingYardsPerAttempt           0
# RushingTouchdowns                0
# FantasyPointsPerGame             0
# FantasyPoints                    0
# Year                             0
# PlayerShortName                  0
# PlayerAgeExact                   0
# PassAttemptsPerGame              0
# CompletionPercentage             0
# MoneyThrows                      0
# TouchdownRate                    0
# ProtectionRate                   0
# PressuredCompletionPercentage    0
# AirYards                         0
# AirYardsPerGame                  0
# AirYardsPerAttempt               0
# DeepBallAttempts                 0
# DeepBallCompletionPercentage     0
# dtype: int64
# Rank                         0
# PlayerID                     0
# Name                         0
# Team                         0
# Position                     0
# Played                       0
# RushingAttempts              0
# RushingYards                 0
# RushingYardsPerAttempt       0
# RushingTouchdowns            0
# ReceivingTargets             0
# Receptions                   0
# ReceivingYards               0
# ReceivingTouchdowns          0
# Fumbles                      0
# FumblesLost                  0
# FantasyPointsPerGame         0
# FantasyPoints                0
# Year                         0
# PlayerShortName              0
# PlayerAgeExact               0
# Carries                      0
# YardsPerCarry               30
# Targets                      0
# ReceivingTDs                 0
# SnapShare                    0
# OpportunityShare             6
# ShotgunCarryRate            58
# ShotgunYardsPerCarry        67
# UnderCenterCarryRate        58
# UnderCenterYardsPerCarry    40
# AverageDefendersInTheBox    58
# StackedFrontCarryRate       58
# BaseFrontCarryRate          58
# LightFrontCarryRate         58
# dtype: int64
# Rank                            0
# PlayerID                        0
# Name                            0
# Team                            0
# Position                        0
# Played                          0
# ReceivingTargets                0
# Receptions                      0
# ReceptionPercentage             0
# ReceivingYards                  0
# ReceivingTouchdowns             0
# ReceivingLong                   0
# ReceivingYardsPerTarget         0
# ReceivingYardsPerReception      0
# RushingAttempts                 0
# RushingYards                    0
# RushingYardsPerAttempt          0
# RushingTouchdowns               0
# Fumbles                         0
# FumblesLost                     0
# FantasyPointsPerGame            0
# FantasyPoints                   0
# Year                            0
# PlayerShortName                 0
# Targets                         0
# HogRate                       114
# SnapShare                       0
# AverageTargetDistance           0
# AirYards                        0
# AirYardsPerGame                 0
# AirYardsPerReception            0
# RedZoneTargets                  0
# EndzoneTargets                  0
# TargetAccuracy                  0
# TargetShare                     0
# FantasyPointsPerTarget          0
# dtype: int64
# Rank                            0
# PlayerID                        0
# Name                            0
# Team                            0
# Position                        0
# Played                          0
# ReceivingTargets                0
# Receptions                      0
# ReceptionPercentage             0
# ReceivingYards                  0
# ReceivingTouchdowns             0
# ReceivingLong                   0
# ReceivingYardsPerTarget         0
# ReceivingYardsPerReception      0
# RushingAttempts                 0
# RushingYards                    0
# RushingYardsPerAttempt          0
# RushingTouchdowns               0
# Fumbles                         0
# FumblesLost                     0
# FantasyPointsPerGame            0
# FantasyPoints                   0
# Year                            0
# PlayerShortName                 0
# Targets                         0
# ReceivingTDs                    0
# HogRate                       325
# SnapShare                       0
# AverageTargetDistance           0
# AirYards                        0
# AirYardsPerGame                 0
# AirYardsPerReception            0
# RedZoneTargets                  0
# EndzoneTargets                  0
# TargetAccuracy                  0
# TargetShare                     0
# FantasyPointsPerTarget          0
# dtype: int64

# %%
for frame in df_list2:
    print(frame.head(1))
# Out:
#    Rank  PlayerID        Name Team Position  Played  PassingCompletions  \
# 0     1     19801  Josh Allen  BUF       QB      17                 409
#
#    PassingAttempts  PassingCompletionPercentage  PassingYards  ...  \
# 0              646                         63.3          4407  ...
#
#    CompletionPercentage  MoneyThrows  TouchdownRate  ProtectionRate  \
# 0                 63.41           29           5.58           77.94
#
#    PressuredCompletionPercentage  AirYards  AirYardsPerGame  \
# 0                          37.83    2785.0           163.82
#
#    AirYardsPerAttempt  DeepBallAttempts  DeepBallCompletionPercentage
# 0                4.31                80                          42.5
#
# [1 rows x 34 columns]
#    Rank  PlayerID             Name Team Position  Played  RushingAttempts  \
# 0     1     21682  Jonathan Taylor  IND       RB      17              332
#
#    RushingYards  RushingYardsPerAttempt  RushingTouchdowns  ...  SnapShare  \
# 0          1811                     5.5                 18  ...      68.56
#
#    OpportunityShare  ShotgunCarryRate  ShotgunYardsPerCarry  \
# 0             70.77             37.65                   1.0
#
#    UnderCenterCarryRate  UnderCenterYardsPerCarry  AverageDefendersInTheBox  \
# 0                 62.34                       1.0                      6.07
#
#    StackedFrontCarryRate BaseFrontCarryRate LightFrontCarryRate
# 0                  13.25              28.31               57.83
#
# [1 rows x 35 columns]
#    Rank  PlayerID          Name Team Position  Played  ReceivingTargets  \
# 0     1     19803  Mark Andrews  BAL       TE      17               154
#
#    Receptions  ReceptionPercentage  ReceivingYards  ...  SnapShare  \
# 0         107                 69.5            1361  ...      76.54
#
#    AverageTargetDistance  AirYards  AirYardsPerGame  AirYardsPerReception  \
# 0                   9.35    1440.0             84.7                  13.5
#
#    RedZoneTargets  EndzoneTargets  TargetAccuracy  TargetShare  \
# 0              20              13            7.35        26.64
#
#    FantasyPointsPerTarget
# 0                    1.96
#
# [1 rows x 36 columns]
#    Rank  PlayerID         Name Team Position  Played  ReceivingTargets  \
# 0     1     18882  Cooper Kupp  LAR       WR      17               191
#
#    Receptions  ReceptionPercentage  ReceivingYards  ...  SnapShare  \
# 0         145                 75.9            1947  ...      94.01
#
#    AverageTargetDistance  AirYards  AirYardsPerGame  AirYardsPerReception  \
# 0                   8.32    1590.0            93.52                  11.0
#
#    RedZoneTargets  EndzoneTargets  TargetAccuracy  TargetShare  \
# 0              38              11            7.76        31.72
#
#    FantasyPointsPerTarget
# 0                     2.3
#
# [1 rows x 37 columns]
