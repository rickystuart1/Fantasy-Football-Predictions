# %%
#Import Dependencies
import psycopg2
import sqlalchemy
from sqlalchemy import create_engine
import pandas as pd 
from config import password

# %%
# Read in CSV
teams_df = pd.read_csv("../../DataBase/Resources/Teams.csv", index_col=0)
teams_df
# Out:
#                           Name Abbreviation Conference Division  Unnamed: 5
# ID
# 1.0          Arizona Cardinals          ARI        NFC     West         NaN
# 2.0            Atlanta Falcons          ATL        NFC    South         NaN
# 3.0           Baltimore Ravens          BAL        AFC    North         NaN
# 4.0              Buffalo Bills          BUF        AFC     East         NaN
# 5.0          Carolina Panthers          CAR        NFC    South         NaN
# 6.0              Chicago Bears          CHI        NFC    North         NaN
# 7.0         Cincinnati Bengals          CIN        AFC    North         NaN
# 8.0           Cleveland Browns          CLE        AFC    North         NaN
# 9.0             Dallas Cowboys          DAL        NFC     East         NaN
# 10.0            Denver Broncos          DEN        AFC     West         NaN
# 11.0             Detroit Lions          DET        NFC    North         NaN
# 12.0         Green Bay Packers           GB        NFC    North         NaN
# 13.0            Houston Texans          HOU        AFC    South         NaN
# 14.0        Indianapolis Colts          IND        AFC    South         NaN
# 15.0      Jacksonville Jaguars          JAX        AFC    South         NaN
# 16.0        Kansas City Chiefs           KC        AFC     West         NaN
# 17.0            Miami Dolphins          MIA        AFC     East         NaN
# 18.0         Minnesota Vikings          MIN        NFC    North         NaN
# 19.0      New England Patriots           NE        AFC     East         NaN
# 20.0        New Orleans Saints           NO        NFC    South         NaN
# 21.0                 NY Giants          NYG        NFC     East         NaN
# 22.0                   NY Jets          NYJ        AFC     East         NaN
# 23.0         Las Vegas Raiders           LV        AFC     West         NaN
# 24.0       Philadelphia Eagles          PHI        NFC     East         NaN
# 25.0       Pittsburgh Steelers          PIT        AFC    North         NaN
# 26.0      Los Angeles Chargers          LAC        AFC     West         NaN
# 27.0       San Francisco 49ers           SF        NFC     West         NaN
# 28.0          Seattle Seahawks          SEA        NFC     West         NaN
# 29.0          Los Angeles Rams          LAR        NFC     West         NaN
# 30.0      Tampa Bay Buccaneers           TB        NFC    South         NaN
# 31.0          Tennessee Titans          TEN        AFC    South         NaN
# 32.0  Washington Football Team          WAS        NFC     East         NaN
# NaN                        NaN          NaN        NaN      NaN         NaN
# NaN                        NaN          NaN        NaN      NaN         NaN
# NaN                        NaN          NaN        NaN      NaN         NaN
# NaN                        NaN          NaN        NaN      NaN         NaN
# NaN                        NaN          NaN        NaN      NaN         NaN
# NaN                        NaN          NaN        NaN      NaN         NaN
# NaN                        NaN          NaN        NaN      NaN         NaN
# NaN                        NaN          NaN        NaN      NaN         NaN
# NaN                        NaN          NaN        NaN      NaN         NaN
# NaN                        NaN          NaN        NaN      NaN         NaN
# NaN                        NaN          NaN        NaN      NaN         NaN
# NaN                        NaN          NaN        NaN      NaN         NaN
# NaN                        NaN          NaN        NaN      NaN         NaN

# %%
#Remove unnamed column
teams_df = teams_df.loc[:, ~teams_df.columns.str.contains('^Unnamed')]

# %%
#remove extra rows
teams_df.dropna(axis = 0, inplace=True)
# Out:
# c:\Users\camke\anaconda3\envs\PythonData\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
#Check clean up
teams_df
# Out:
#                           Name Abbreviation Conference Division
# ID
# 1.0          Arizona Cardinals          ARI        NFC     West
# 2.0            Atlanta Falcons          ATL        NFC    South
# 3.0           Baltimore Ravens          BAL        AFC    North
# 4.0              Buffalo Bills          BUF        AFC     East
# 5.0          Carolina Panthers          CAR        NFC    South
# 6.0              Chicago Bears          CHI        NFC    North
# 7.0         Cincinnati Bengals          CIN        AFC    North
# 8.0           Cleveland Browns          CLE        AFC    North
# 9.0             Dallas Cowboys          DAL        NFC     East
# 10.0            Denver Broncos          DEN        AFC     West
# 11.0             Detroit Lions          DET        NFC    North
# 12.0         Green Bay Packers           GB        NFC    North
# 13.0            Houston Texans          HOU        AFC    South
# 14.0        Indianapolis Colts          IND        AFC    South
# 15.0      Jacksonville Jaguars          JAX        AFC    South
# 16.0        Kansas City Chiefs           KC        AFC     West
# 17.0            Miami Dolphins          MIA        AFC     East
# 18.0         Minnesota Vikings          MIN        NFC    North
# 19.0      New England Patriots           NE        AFC     East
# 20.0        New Orleans Saints           NO        NFC    South
# 21.0                 NY Giants          NYG        NFC     East
# 22.0                   NY Jets          NYJ        AFC     East
# 23.0         Las Vegas Raiders           LV        AFC     West
# 24.0       Philadelphia Eagles          PHI        NFC     East
# 25.0       Pittsburgh Steelers          PIT        AFC    North
# 26.0      Los Angeles Chargers          LAC        AFC     West
# 27.0       San Francisco 49ers           SF        NFC     West
# 28.0          Seattle Seahawks          SEA        NFC     West
# 29.0          Los Angeles Rams          LAR        NFC     West
# 30.0      Tampa Bay Buccaneers           TB        NFC    South
# 31.0          Tennessee Titans          TEN        AFC    South
# 32.0  Washington Football Team          WAS        NFC     East

# %%
#format columns to lower case for db
teams_df.columns = teams_df.columns.str.lower()

# %% [markdown]
# Start SQL Imports

# %%
#Create connection to AWS database
ENDPOINT="fantasyfootball.ckswyhqaro8q.us-east-2.rds.amazonaws.com"
PORT="5432"
USR="DreamTeam"
PSSWD=password
DBNAME="postgres"

#conn_string = "host='localhost' dbname='my_database' user='postgres' password='secret'
con= "postgresql://{}:{}@{}:{}/{}".format(USR, PSSWD, ENDPOINT, PORT, DBNAME)

# %%
#Write table to AWS
teams_df.to_sql("teams", con, if_exists="replace")
